# %%
import sys
from IPython.display import Image
import numpy as np

def test_range(a):
    if a in range(0,20):
        s=Image(filename = r"Sad\sad1.png" , width =400  , height =300)
        display(s)        
    elif a in range (20,40):
        s=Image(filename = r"Sad\sad2.png" , width =400  , height =300)
        display(s)
    elif a in range (40,60):
        s=Image(filename = r"Sad\sad3.png" , width =400  , height =300)
        display(s)
    elif a in range (60,80):
        s=Image(filename = r"Sad\sad4.png" , width =400  , height =300)
        display(s)
    elif a in range  (80,100):
        s=Image(filename = r"Sad\sad5.png" , width =400  , height =300)
        display(s)
    else:
        print("no emoji")


a = int(input('Enter the percentage :  '))
test_range(a)
# Out:
# Enter the percentage :  23
